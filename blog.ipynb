# %% [markdown]
# <a href="https://colab.research.google.com/github/haskinse/bee2041_empirical_project/blob/main/blog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive # connect to google drive
drive.mount("/content/drive")

project_path = "/content/drive/MyDrive/bee2041_empirical_project" # define project path
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <style>
# body {
#   font-family: Arial, sans-serif;
#   line-height: 1.6;
# }
#
# .container {
#   width: 85% !important;
#   max-width: 1000px;
# }
#
# h1 {
#   font-size: 42px;
#   margin-top: 20px;
#   margin-bottom: 15px;
# }
#
# h2 {
#   font-size: 30px;
#   margin-top: 40px;
#   margin-bottom: 15px;
# }
#
# p, li {
#   font-size: 18px;
# }
#
# .nav-buttons {
#   margin: 20px 0 30px 0;
# }
#
# .nav-buttons button {
#   background-color: #f7c6d9;
#   border: none;
#   padding: 10px 18px;
#   margin-right: 10px;
#   border-radius: 10px;
#   cursor: pointer;
#   font-size: 16px;
# }
#
# .nav-buttons button:hover {
#   opacity: 0.85;
# }
#
# .figure-grid {
#   display: flex;
#   gap: 20px;
#   flex-wrap: wrap;
#   justify-content: center;
#   margin-top: 20px;
#   margin-bottom: 20px;
# }
#
# .figure-grid img {
#   width: 48%;
#   border-radius: 8px;
# }
#
# .center-figure {
#   text-align: center;
#   margin: 20px 0;
# }
#
# .center-figure img {
#   max-width: 100%;
#   border-radius: 8px;
# }
# </style>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#   <title>What Makes a Taylor Swift Song Successful?</title>
#   <link rel="stylesheet" href="style.css">
# </head>
#
# <body>
#   <section class="hero">
#     <h1>What Makes a Taylor Swift Song Successful?</h1>
#
#     <p>
#       Taylor Swift is one of the most successful music artists of all time.
#       She has sold over 100 million album units, and multiple of her songs
#       have surpassed one billion streams. But what actually drives her success?
#       Is there something in the music itself that explains her dominance, or is
#       it something else entirely?
#     </p>
#
#     <p>
#       This blog analyses the musical features of Taylor Swift’s music to see
#       whether certain characteristics are associated with success. Are there
#       patterns in which tracks become globally popular while others remain less
#       prominent? Or is her success a product of more than just the music itself?
#     </p>
#   </section>
# </body>
# </html>

# %% [markdown]
# ## Where does the data come from?
#
# Data for this project came from a range of sources. Album-level success data was scraped from Wikipedia, while track-level data was collected from a Kaggle dataset and APIs from Spotify and Last.fm.
#
# Taylor Swift was an ideal artist to study because there is an unusually large amount of data available on her individual tracks. Features such as tempo, key and energy are available at song level, allowing for a much more detailed analysis than would be possible for many other artists.

# %% [markdown]
# ## How is success measured?
#
# Success is measured in different ways depending on the level of analysis.
#
# - **Album success** is measured using total certified units sold
# - **Track success** is measured using listener counts and play count
#
# This allows both a broad view of album performance and a more detailed track-level analysis.

# %% [markdown]
# <h2 id="albums">Which of Taylor Swift’s albums have been most successful?</h2>

# %% [markdown]
# <div class="center-figure">
#   <img src="output/figures/commercial_success/total_units_bar.png" alt="Most successful Taylor Swift songs">
# </div>

# %% [markdown]
# The most successful album by a large margin is *1989*, with over 20 million units sold in total. Around 15 million came from its original release, with a further 5 million from the *Taylor’s Version* re-release.
#
# More broadly, album success appears remarkably consistent across Swift’s career. While older albums do have higher total unit counts, these have also had longer to accumulate sales, so this should not be interpreted as clear evidence that earlier music was inherently stronger.

# %% [markdown]
# <h2 id="songs">Which songs have been most successful?</h2>

# %% [markdown]
# <div class="center-figure">
#   <img src="output/figures/commercial_success/top_16_track_listens.png" alt="Most successful Taylor Swift songs">
# </div>

# %% [markdown]
# Looking at individual tracks, a small number of songs dominate total listeners while the majority receive far fewer. This creates a clear “long tail” distribution, where only a few songs become extremely large hits.
#
# Among the very top songs, *1989* is especially strong, but there is still a relatively balanced spread across albums overall. Again, older songs have had longer to build up listens, so age is likely part of this pattern.

# %% [markdown]
# <h2 id="time">How has Taylor Swift’s music changed over time?</h2>

# %% [markdown]
# Taylor Swift is often described as a “chameleon” because of her ability to shift both genre and sound. Her earliest albums, such as *Taylor Swift* and *Fearless*, are clearly country, while later albums like *1989* and *Red* move much further toward pop. More recent albums explore indie, folk-pop and alternative influences.
#
# However, when looking at measurable track features, her music is often more stable over time than this reputation might suggest.

# %% [markdown]
# <div class="figure-grid">
#   <img src="output/figures/track_feature_time/track_acousticness_time.png" alt="Acousticness over time">
#   <img src="output/figures/track_feature_time/track_danceability_time.png" alt="Danceability over time">
#   <img src="output/figures/track_feature_time/track_duration_min_time.png" alt="Duration in minutes over time">
#   <img src="output/figures/track_feature_time/track_energy_time.png" alt="Energy over time">
# </div>

# %% [markdown]
# <div class="figure-grid">
#   <img src="output/figures/track_feature_time/track_explicit_time.png" alt="Explicitness over time">
#   <img src="output/figures/track_feature_time/track_instrumentalness_time.png" alt="Instrumentalness over time">
#   <img src="output/figures/track_feature_time/track_liveness_time.png" alt="Liveness over time">
#   <img src="output/figures/track_feature_time/track_loudness_time.png" alt="Loudness over time">
# </div>

# %% [markdown]
# <div class="figure-grid">
#   <img src="output/figures/track_feature_time/track_speechiness_time.png" alt="Speechiness over time">
#   <img src="output/figures/track_feature_time/track_tempo_time.png" alt="Tempo over time">
#   <img src="output/figures/track_feature_time/track_valence_time.png" alt="Valence over time">
# </div>

# %% [markdown]
# Overall, many of the core track features are more stable than expected. Tempo, energy and danceability remain relatively consistent across eras, suggesting that the underlying structure of Swift’s music changes less dramatically than the genre labels alone might imply.
#
# The clearest changes appear in acousticness and explicitness. Acousticness varies much more noticeably across eras, while later albums contain a much greater share of explicit tracks. This suggests that although her overall musical profile remains fairly stable, some stylistic elements do shift in meaningful ways.

# %% [markdown]
# <h2 id="success">How are these features related to success?</h2>

# %% [markdown]
# To explore whether musical features influence popularity, I plotted each feature against track success, measured using log listeners. If certain features consistently made songs more successful, these graphs should show clear upward or downward patterns.

# %% [markdown]
# <div class="figure-grid">
#   <img src="output/figures/track_feature_success/track_acousticness_success.png" alt="Acousticness over success">
#   <img src="output/figures/track_feature_success/track_danceability_success.png" alt="Danceability over success">
#   <img src="output/figures/track_feature_success/track_duration_min_success.png" alt="Duration in minutes over success">
#   <img src="output/figures/track_feature_success/track_energy_success.png" alt="Energy over success">
# </div>

# %% [markdown]
# <div class="figure-grid">
#   <img src="output/figures/track_feature_success/track_explicit_success.png" alt="Explicitness over success">
#   <img src="output/figures/track_feature_success/track_instrumentalness_success.png" alt="Instrumentalness over success">
#   <img src="output/figures/track_feature_success/track_liveness_success.png" alt="Liveness over success">
#   <img src="output/figures/track_feature_success/track_loudness_success.png" alt="Loudness over success">
# </div>

# %% [markdown]
# <div class="figure-grid">
#   <img src="output/figures/track_feature_success/track_speechiness_success.png" alt="Speechiness over success">
#   <img src="output/figures/track_feature_success/track_tempo_success.png" alt="Tempo over success">
#   <img src="output/figures/track_feature_success/track_valence_success.png" alt="Valence over success">
# </div>

# %% [markdown]
# Across almost all features, the relationships are weak. Most of the trend lines are close to flat, and there is no strong visual evidence that any single musical characteristic systematically drives success.
#
# This is an important result. It suggests that Taylor Swift’s popularity is not easily explained by measurable audio features such as energy, tempo or danceability alone.

# %% [markdown]
# ## Are some features too similar to each other?

# %% [markdown]
# <div class="center-figure">
#   <img src="output/figures/correlation_matrices/track_feature_correlations.png" alt="Correlation matrix of track features and success">
# </div>

# %% [markdown]
# The correlation matrix shows that some features are strongly related to each other. In particular, energy, loudness and valence are all quite closely associated.
#
# This matters because highly correlated predictors can make regression coefficients less stable and harder to interpret. In other words, if several variables are capturing very similar information, it becomes harder for the model to separate their individual effects.

# %% [markdown]
# <h2 id="regression">What do the regression results show?</h2>

# %% [markdown]
# To test these relationships more formally, I estimated regressions using track-level musical features to predict success, measured as log listeners.
#
# The results were consistent with the visual analysis:
#
# - coefficients were generally small
# - explanatory power was low
# - and no simple combination of musical features strongly predicted which songs would become especially popular
#
# This suggests that standard audio features are only a weak explanation of success within Taylor Swift’s discography.

# %% [markdown]
# Taken together, these results suggest that Taylor Swift’s success is not primarily determined by observable musical features.
#
# This is perhaps the most interesting finding of the project. Despite analysing a wide range of audio characteristics, there is little evidence that any single one consistently explains why some songs become much more popular than others.
#
# Instead, success likely depends on broader factors beyond the music itself, such as cultural influence, fan engagement, branding, timing, and narrative.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This project set out to test whether musical features could explain the success of Taylor Swift’s songs.
#
# While her music does evolve across eras, especially in features such as acousticness and explicitness, the broader conclusion is that measurable audio features alone do not strongly predict popularity. The relationships are weak, the regressions have low explanatory power, and much of Swift’s success appears to come from factors beyond the sound of the music itself.
#
# In that sense, Taylor Swift’s success seems to be about more than just the songs. It reflects a wider combination of identity, cultural relevance and audience connection that cannot be fully captured through track-level features alone.

# %%
# !jupyter nbconvert --to html "{project_path}/blog.ipynb" --output "index.html" --output-dir "{project_path}/docs" --no-input --no-prompt
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/traitlets/traitlets.py", line 653, in get
#     value = obj._trait_values[self.name]
#             ~~~~~~~~~~~~~~~~~^^^^^^^^^^^
# KeyError: 'template_paths'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/traitlets/traitlets.py", line 653, in get
#     value = obj._trait_values[self.name]
#             ~~~~~~~~~~~~~~~~~^^^^^^^^^^^
# KeyError: 'extra_template_basedirs'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/jupyter-nbconvert", line 4, in <module>
#     from nbconvert.nbconvertapp import main
# ...

# %%
# !git config --global user.name "haskinse"
# !git config --global user.email "elh253@exeter.ac.uk"
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# fatal: Unable to read current working directory: Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# fatal: Unable to read current working directory: Transport endpoint is not connected

# %%
# %cd "/content/drive/MyDrive/bee2041_empirical_project"

# !git add .
# !git commit -m "Update blog images"
# !git push
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1056/2463126300.py", line 1, in <cell line: 0>
#     get_ipython().run_line_magic('cd', '"/content/drive/MyDrive/bee2041_empirical_project"')
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "<decorator-gen-85>", line 2, in cd
# ...
